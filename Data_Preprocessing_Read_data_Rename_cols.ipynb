# %%
import pandas as pd

# %% [markdown]
# # READING TABLE .tsv file ,read_table

# %%
tab=pd.read_table("https://raw.githubusercontent.com/jymishra/datasets/master/chipotle.tsv")

# %%
tab.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# # READING TABLE separated by | and no HEADER

# %%
usr=pd.read_table("https://raw.githubusercontent.com/jymishra/datasets/master/u.user")

# %%
usr.head()
# Out:
#    1|24|M|technician|85711
# 0       2|53|F|other|94043
# 1      3|23|M|writer|32067
# 2  4|24|M|technician|43537
# 3       5|33|F|other|15213
# 4   6|42|M|executive|98101

# %%
usr=pd.read_table("https://raw.githubusercontent.com/jymishra/datasets/master/u.user",
                  sep='|')

# %%
usr.head()
# Out:
#    1  24  M  technician  85711
# 0  2  53  F       other  94043
# 1  3  23  M      writer  32067
# 2  4  24  M  technician  43537
# 3  5  33  F       other  15213
# 4  6  42  M   executive  98101

# %%
usr=pd.read_table("https://raw.githubusercontent.com/jymishra/datasets/master/u.user",
                  sep='|',
                  header=None)

# %%
usr.head()
# Out:
#    0   1  2           3      4
# 0  1  24  M  technician  85711
# 1  2  53  F       other  94043
# 2  3  23  M      writer  32067
# 3  4  24  M  technician  43537
# 4  5  33  F       other  15213

# %%
usr.columns=['1st Col','2nd Col','3rd Col','4th Col','5th Col']

# %%
usr.head()
# Out:
#    1st Col  2nd Col 3rd Col     4th Col 5th Col
# 0        1       24       M  technician   85711
# 1        2       53       F       other   94043
# 2        3       23       M      writer   32067
# 3        4       24       M  technician   43537
# 4        5       33       F       other   15213

# %% [markdown]
# # Other way of Renaming while loading

# %%
col_names=['ID', 'Age', 'Sex', 'Occupation', 'ZIP']

# %%
usr1=pd.read_table("https://raw.githubusercontent.com/jymishra/datasets/master/u.user",
                  sep='|',
                  header=None,
                  names=col_names)

# %%
usr1.head()
# Out:
#    ID  Age Sex  Occupation    ZIP
# 0   1   24   M  technician  85711
# 1   2   53   F       other  94043
# 2   3   23   M      writer  32067
# 3   4   24   M  technician  43537
# 4   5   33   F       other  15213

# %% [markdown]
# # Selecting Columns while loading data

# %%
ds=pd.read_csv('https://raw.githubusercontent.com/jymishra/datasets/master/citizen.csv')

# %%
ds.head()
# Out:
#    Country   Age  Gender Occupation Employment Status Employement Type  \
# 0   Poland  34.0    Male   Salaried               Yes        Permanent
# 1    Spain  42.0  Female   Business               Yes        Temporary
# 2  Germany  29.0    Male   Business                No        Temporary
# 3    Spain  38.0    Male   Business                No        Permanent
# 4  Germany  32.0    Male   Salaried               NaN        Permanent
#
#     Salary Purchased
# 0  72000.0        No
# 1  48000.0       Yes
# 2  54000.0        No
# 3  61000.0        No
# 4      NaN       Yes

# %%
ds1=pd.read_csv('https://raw.githubusercontent.com/jymishra/datasets/master/citizen.csv',
               usecols=['Age','Gender','Occupation'])

# %%
ds1.head()
# Out:
#     Age  Gender Occupation
# 0  34.0    Male   Salaried
# 1  42.0  Female   Business
# 2  29.0    Male   Business
# 3  38.0    Male   Business
# 4  32.0    Male   Salaried

# %% [markdown]
# # Skip few rows from last /first

# %%
ds2=pd.read_csv('https://raw.githubusercontent.com/jymishra/datasets/master/citizen.csv')

# %%
ds2.head(10)
# Out:
#    Country   Age  Gender Occupation Employment Status Employement Type  \
# 0   Poland  34.0    Male   Salaried               Yes        Permanent
# 1    Spain  42.0  Female   Business               Yes        Temporary
# 2  Germany  29.0    Male   Business                No        Temporary
# 3    Spain  38.0    Male   Business                No        Permanent
# 4  Germany  32.0    Male   Salaried               NaN        Permanent
# 5   Poland  31.0  Female   Business               Yes        Temporary
# 6    India   NaN  Female   Salaried               NaN        Temporary
# 7   Poland  22.0  Female   Salaried               Yes    Self Employed
# 8    India  38.0    Male   Business                No              NaN
# 9   Poland  49.0    Male        NaN               Yes    Self Employed
#
#     Salary Purchased
# 0  72000.0        No
# 1  48000.0       Yes
# 2  54000.0        No
# 3  61000.0        No
# 4      NaN       Yes
# 5  58000.0       Yes
# 6  52000.0        No
# ...

# %%
ds2.tail(10)
# Out:
#     Country   Age  Gender Occupation Employment Status Employement Type  \
# 10   Brazil  34.0    Male   Salaried                No        Permanent
# 11    Spain  42.0  Female   Business                No        Temporary
# 12  Germany  29.0  Female   Business                No        Temporary
# 13    Spain  38.0    Male   Business                No        Permanent
# 14  Germany   NaN    Male   Salaried               Yes        Permanent
# 15   Brazil  32.0  Female   Business               Yes        Temporary
# 16    Spain   NaN  Female   Salaried               Yes        Temporary
# 17  England  22.0  Female   Salaried               Yes              NaN
# 18  Germany  38.0    Male   Business               Yes              NaN
# 19  England  45.0    Male        NaN               NaN    Self Employed
#
#      Salary Purchased
# 10  70000.0        No
# 11  48000.0       Yes
# 12  54000.0        No
# 13  61000.0        No
# 14      NaN       Yes
# 15  58000.0       Yes
# ...

# %%
ds3=pd.read_csv('https://raw.githubusercontent.com/jymishra/datasets/master/citizen.csv',skiprows=5)

# %%
ds3.head()
# Out:
#   Germany    32    Male  Salaried Unnamed: 4      Permanent  Unnamed: 6  Yes
# 0  Poland  31.0  Female  Business        Yes      Temporary     58000.0  Yes
# 1   India   NaN  Female  Salaried        NaN      Temporary     52000.0   No
# 2  Poland  22.0  Female  Salaried        Yes  Self Employed     79000.0  Yes
# 3   India  38.0    Male  Business         No            NaN         NaN   No
# 4  Poland  49.0    Male       NaN        Yes  Self Employed     67000.0  Yes

# %%
ds4=pd.read_csv('https://raw.githubusercontent.com/jymishra/datasets/master/citizen.csv',skipfooter=5)
# Out:
# /Users/jymisra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
ds4.tail(10)
# Out:
#     Country   Age  Gender Occupation Employment Status Employement Type  \
# 5    Poland  31.0  Female   Business               Yes        Temporary
# 6     India   NaN  Female   Salaried               NaN        Temporary
# 7    Poland  22.0  Female   Salaried               Yes    Self Employed
# 8     India  38.0    Male   Business                No              NaN
# 9    Poland  49.0    Male        NaN               Yes    Self Employed
# 10   Brazil  34.0    Male   Salaried                No        Permanent
# 11    Spain  42.0  Female   Business                No        Temporary
# 12  Germany  29.0  Female   Business                No        Temporary
# 13    Spain  38.0    Male   Business                No        Permanent
# 14  Germany   NaN    Male   Salaried               Yes        Permanent
#
#      Salary Purchased
# 5   58000.0       Yes
# 6   52000.0        No
# 7   79000.0       Yes
# 8       NaN        No
# 9   67000.0       Yes
# 10  70000.0        No
# ...

# %% [markdown]
# # Replacing certain values to NaN  during upload

# %%
ds
# Out:
#     Country   Age  Gender Occupation Employment Status Employement Type  \
# 0    Poland  34.0    Male   Salaried               Yes        Permanent
# 1     Spain  42.0  Female   Business               Yes        Temporary
# 2   Germany  29.0    Male   Business                No        Temporary
# 3     Spain  38.0    Male   Business                No        Permanent
# 4   Germany  32.0    Male   Salaried               NaN        Permanent
# 5    Poland  31.0  Female   Business               Yes        Temporary
# 6     India   NaN  Female   Salaried               NaN        Temporary
# 7    Poland  22.0  Female   Salaried               Yes    Self Employed
# 8     India  38.0    Male   Business                No              NaN
# 9    Poland  49.0    Male        NaN               Yes    Self Employed
# 10   Brazil  34.0    Male   Salaried                No        Permanent
# 11    Spain  42.0  Female   Business                No        Temporary
# ...

# %%
ds1=pd.read_csv('https://raw.githubusercontent.com/jymishra/datasets/master/citizen.csv',
             na_values=['Male','61000'])

# %%
ds1
# Out:
#     Country   Age  Gender Occupation Employment Status Employement Type  \
# 0    Poland  34.0     NaN   Salaried               Yes        Permanent
# 1     Spain  42.0  Female   Business               Yes        Temporary
# 2   Germany  29.0     NaN   Business                No        Temporary
# 3     Spain  38.0     NaN   Business                No        Permanent
# 4   Germany  32.0     NaN   Salaried               NaN        Permanent
# 5    Poland  31.0  Female   Business               Yes        Temporary
# 6     India   NaN  Female   Salaried               NaN        Temporary
# 7    Poland  22.0  Female   Salaried               Yes    Self Employed
# 8     India  38.0     NaN   Business                No              NaN
# 9    Poland  49.0     NaN        NaN               Yes    Self Employed
# 10   Brazil  34.0     NaN   Salaried                No        Permanent
# 11    Spain  42.0  Female   Business                No        Temporary
# ...

# %%
ds2=pd.read_csv('https://raw.githubusercontent.com/jymishra/datasets/master/citizen.csv',
              index_col='Country')

# %%
ds2.head()
# Out:
#           Age  Gender Occupation Employment Status Employement Type   Salary  \
# Country
# Poland   34.0    Male   Salaried               Yes        Permanent  72000.0
# Spain    42.0  Female   Business               Yes        Temporary  48000.0
# Germany  29.0    Male   Business                No        Temporary  54000.0
# Spain    38.0    Male   Business                No        Permanent  61000.0
# Germany  32.0    Male   Salaried               NaN        Permanent      NaN
#
#         Purchased
# Country
# Poland         No
# Spain         Yes
# Germany        No
# Spain          No
# Germany       Yes

# %%
ds2
# Out:
#           Age  Gender Occupation Employment Status Employement Type   Salary  \
# Country
# Poland   34.0    Male   Salaried               Yes        Permanent  72000.0
# Spain    42.0  Female   Business               Yes        Temporary  48000.0
# Germany  29.0    Male   Business                No        Temporary  54000.0
# Spain    38.0    Male   Business                No        Permanent  61000.0
# Germany  32.0    Male   Salaried               NaN        Permanent      NaN
# Poland   31.0  Female   Business               Yes        Temporary  58000.0
# India     NaN  Female   Salaried               NaN        Temporary  52000.0
# Poland   22.0  Female   Salaried               Yes    Self Employed  79000.0
# India    38.0    Male   Business                No              NaN      NaN
# Poland   49.0    Male        NaN               Yes    Self Employed  67000.0
# Brazil   34.0    Male   Salaried                No        Permanent  70000.0
# ...

# %%
ds2.loc['Poland']
# Out:
#           Age  Gender Occupation Employment Status Employement Type   Salary  \
# Country
# Poland   34.0    Male   Salaried               Yes        Permanent  72000.0
# Poland   31.0  Female   Business               Yes        Temporary  58000.0
# Poland   22.0  Female   Salaried               Yes    Self Employed  79000.0
# Poland   49.0    Male        NaN               Yes    Self Employed  67000.0
#
#         Purchased
# Country
# Poland         No
# Poland        Yes
# Poland        Yes
# Poland        Yes

# %%
ds2.loc[['Poland','Germany']]
# Out:
#           Age  Gender Occupation Employment Status Employement Type   Salary  \
# Country
# Poland   34.0    Male   Salaried               Yes        Permanent  72000.0
# Poland   31.0  Female   Business               Yes        Temporary  58000.0
# Poland   22.0  Female   Salaried               Yes    Self Employed  79000.0
# Poland   49.0    Male        NaN               Yes    Self Employed  67000.0
# Germany  29.0    Male   Business                No        Temporary  54000.0
# Germany  32.0    Male   Salaried               NaN        Permanent      NaN
# Germany  29.0  Female   Business                No        Temporary  54000.0
# Germany   NaN    Male   Salaried               Yes        Permanent      NaN
# Germany  38.0    Male   Business               Yes              NaN      NaN
#
#         Purchased
# Country
# Poland         No
# Poland        Yes
# Poland        Yes
# Poland        Yes
# Germany        No
# Germany       Yes
# Germany        No
# Germany       Yes
# ...

# %%
ds2=pd.read_csv('https://raw.githubusercontent.com/jymishra/datasets/master/citizen.csv')

# %%
ds2.columns
# Out:
# Index(['Country', 'Age', 'Gender', 'Occupation', 'Employment Status',
#        'Employement Type', 'Salary', 'Purchased'],
#       dtype='object')

# %%
ds2.rename(columns={'Country':'COUNTRY','Age':'AGE'})
# Out:
#     COUNTRY   AGE  Gender Occupation Employment Status Employement Type  \
# 0    Poland  34.0    Male   Salaried               Yes        Permanent
# 1     Spain  42.0  Female   Business               Yes        Temporary
# 2   Germany  29.0    Male   Business                No        Temporary
# 3     Spain  38.0    Male   Business                No        Permanent
# 4   Germany  32.0    Male   Salaried               NaN        Permanent
# 5    Poland  31.0  Female   Business               Yes        Temporary
# 6     India   NaN  Female   Salaried               NaN        Temporary
# 7    Poland  22.0  Female   Salaried               Yes    Self Employed
# 8     India  38.0    Male   Business                No              NaN
# 9    Poland  49.0    Male        NaN               Yes    Self Employed
# 10   Brazil  34.0    Male   Salaried                No        Permanent
# 11    Spain  42.0  Female   Business                No        Temporary
# ...

# %%
ds2.columns=ds2.columns.str.upper()

# %%
ds2.head()
# Out:
#    COUNTRY   AGE  GENDER OCCUPATION EMPLOYMENT STATUS EMPLOYEMENT TYPE  \
# 0   Poland  34.0    Male   Salaried               Yes        Permanent
# 1    Spain  42.0  Female   Business               Yes        Temporary
# 2  Germany  29.0    Male   Business                No        Temporary
# 3    Spain  38.0    Male   Business                No        Permanent
# 4  Germany  32.0    Male   Salaried               NaN        Permanent
#
#     SALARY PURCHASED
# 0  72000.0        No
# 1  48000.0       Yes
# 2  54000.0        No
# 3  61000.0        No
# 4      NaN       Yes

# %%
ds2.columns=ds2.columns.str.replace(" ","-")

# %%
ds2.head()
# Out:
#    COUNTRY   AGE  GENDER OCCUPATION EMPLOYMENT-STATUS EMPLOYEMENT-TYPE  \
# 0   Poland  34.0    Male   Salaried               Yes        Permanent
# 1    Spain  42.0  Female   Business               Yes        Temporary
# 2  Germany  29.0    Male   Business                No        Temporary
# 3    Spain  38.0    Male   Business                No        Permanent
# 4  Germany  32.0    Male   Salaried               NaN        Permanent
#
#     SALARY PURCHASED
# 0  72000.0        No
# 1  48000.0       Yes
# 2  54000.0        No
# 3  61000.0        No
# 4      NaN       Yes

# %%
ds2.columns=ds2.columns.str.lower()

# %%
ds2.head()
# Out:
#    country   age  gender occupation employment-status employement-type  \
# 0   Poland  34.0    Male   Salaried               Yes        Permanent
# 1    Spain  42.0  Female   Business               Yes        Temporary
# 2  Germany  29.0    Male   Business                No        Temporary
# 3    Spain  38.0    Male   Business                No        Permanent
# 4  Germany  32.0    Male   Salaried               NaN        Permanent
#
#     salary purchased
# 0  72000.0        No
# 1  48000.0       Yes
# 2  54000.0        No
# 3  61000.0        No
# 4      NaN       Yes

# %%
ds2.columns=ds2.columns.str.capitalize()

# %%
ds2.head()
# Out:
#    Country   Age  Gender Occupation Employment-status Employement-type  \
# 0   Poland  34.0    Male   Salaried               Yes        Permanent
# 1    Spain  42.0  Female   Business               Yes        Temporary
# 2  Germany  29.0    Male   Business                No        Temporary
# 3    Spain  38.0    Male   Business                No        Permanent
# 4  Germany  32.0    Male   Salaried               NaN        Permanent
#
#     Salary Purchased
# 0  72000.0        No
# 1  48000.0       Yes
# 2  54000.0        No
# 3  61000.0        No
# 4      NaN       Yes

# %%
ds2.Country.str.upper()
# Out:
# 0      POLAND
# 1       SPAIN
# 2     GERMANY
# 3       SPAIN
# 4     GERMANY
# 5      POLAND
# 6       INDIA
# 7      POLAND
# 8       INDIA
# 9      POLAND
# 10     BRAZIL
# 11      SPAIN
# 12    GERMANY
# 13      SPAIN
# 14    GERMANY
# 15     BRAZIL
# 16      SPAIN
# 17    ENGLAND
# 18    GERMANY
# 19    ENGLAND
# Name: Country, dtype: object

# %%
ds2.Country=ds2.Country.str.upper()

# %%
ds2
# Out:
#     Country   Age  Gender Occupation Employment-status Employement-type  \
# 0    POLAND  34.0    Male   Salaried               Yes        Permanent
# 1     SPAIN  42.0  Female   Business               Yes        Temporary
# 2   GERMANY  29.0    Male   Business                No        Temporary
# 3     SPAIN  38.0    Male   Business                No        Permanent
# 4   GERMANY  32.0    Male   Salaried               NaN        Permanent
# 5    POLAND  31.0  Female   Business               Yes        Temporary
# 6     INDIA   NaN  Female   Salaried               NaN        Temporary
# 7    POLAND  22.0  Female   Salaried               Yes    Self Employed
# 8     INDIA  38.0    Male   Business                No              NaN
# 9    POLAND  49.0    Male        NaN               Yes    Self Employed
# 10   BRAZIL  34.0    Male   Salaried                No        Permanent
# 11    SPAIN  42.0  Female   Business                No        Temporary
# ...
