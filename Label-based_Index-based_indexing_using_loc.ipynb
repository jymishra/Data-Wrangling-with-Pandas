# %%
import pandas as pd

# %%
ufo=pd.read_csv('https://raw.githubusercontent.com/jymishra/datasets/master/ufo.csv')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.City.value_counts()
# Out:
# Seattle                      187
# New York City                161
# Phoenix                      137
# Houston                      108
# Las Vegas                    105
# Portland                     102
# San Diego                    101
# Los Angeles                   98
# Chicago                       73
# Austin                        62
# Miami                         60
# Tucson                        58
# Columbus                      55
# Albuquerque                   54
# Tacoma                        52
# Dallas                        52
# St. Louis                     51
# San Francisco                 51
# Spokane                       49
# Salem                         48
# Auburn                        48
# Jacksonville                  48
# Sacramento                    46
# Salt Lake City                46
# Gilbert                       45
# Colorado Springs              44
# Denver                        44
# San Antonio                   43
# ...

# %%
ufo.set_index('City',inplace=True)

# %%
ufo.head()
# Out:
#                      Colors Reported Shape Reported State             Time
# City
# Ithaca                           NaN       TRIANGLE    NY   6/1/1930 22:00
# Willingboro                      NaN          OTHER    NJ  6/30/1930 20:00
# Holyoke                          NaN           OVAL    CO  2/15/1931 14:00
# Abilene                          NaN           DISK    KS   6/1/1931 13:00
# New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.shape
# Out:
# (18241, 4)

# %%
type(ufo.index.value_counts())
# Out:
# pandas.core.series.Series

# %%
ufo.index.value_counts()['Holyoke']
# Out:
# 5

# %%
ufo.loc['Holyoke']
# Out:
#         Colors Reported Shape Reported State              Time
# City
# Holyoke             NaN           OVAL    CO   2/15/1931 14:00
# Holyoke             NaN           DISK    MA   1/20/1963 22:00
# Holyoke             NaN           DISK    MA    6/5/1976 23:00
# Holyoke             NaN          LIGHT    MA    4/1/1995 18:00
# Holyoke             NaN        DIAMOND    MA  12/28/2000 18:00

# %%
ufo.loc[['Holyoke','Abilene']]
# Out:
#         Colors Reported Shape Reported State              Time
# City
# Holyoke             NaN           OVAL    CO   2/15/1931 14:00
# Holyoke             NaN           DISK    MA   1/20/1963 22:00
# Holyoke             NaN           DISK    MA    6/5/1976 23:00
# Holyoke             NaN          LIGHT    MA    4/1/1995 18:00
# Holyoke             NaN        DIAMOND    MA  12/28/2000 18:00
# Abilene             NaN           DISK    KS    6/1/1931 13:00
# Abilene             NaN       TRIANGLE    TX     9/1/1991 1:00
# Abilene             NaN         SPHERE    TX    7/15/1995 0:00
# Abilene             NaN            NaN    KS  10/14/1995 23:20
# Abilene             NaN            NaN    TX  10/19/1997 20:45

# %%
ufo.loc['San Jose','Colors Reported':'Time']
# Out:
#          Colors Reported Shape Reported State              Time
# City
# San Jose            BLUE        CHEVRON    CA   7/15/1947 21:00
# San Jose             NaN           DISK    CA    7/4/1966 17:15
# San Jose             NaN         CIRCLE    CA   7/20/1968 19:00
# San Jose           GREEN          LIGHT    CA  11/13/1969 21:03
# San Jose             NaN       TRIANGLE    CA   6/15/1973 22:30
# San Jose             NaN       FIREBALL    CA   10/20/1974 7:00
# San Jose             NaN            NaN    CA    6/30/1975 0:00
# San Jose             NaN         SPHERE    CA    6/30/1976 7:00
# San Jose             NaN           DISK    CA    8/1/1976 21:00
# San Jose             NaN          FLASH    CA   6/30/1977 20:30
# San Jose             NaN           DISK    CA   6/15/1979 20:00
# San Jose             NaN           DISK    CA  10/15/1981 16:30
# San Jose           GREEN          LIGHT    CA  10/14/1986 20:30
# San Jose             NaN       TRIANGLE    CA  10/17/1989 21:00
# ...

# %%
ufo.loc[['Holyoke','San Diego'],'Colors Reported':'Time']
# Out:
#           Colors Reported Shape Reported State              Time
# City
# Holyoke               NaN           OVAL    CO   2/15/1931 14:00
# Holyoke               NaN           DISK    MA   1/20/1963 22:00
# Holyoke               NaN           DISK    MA    6/5/1976 23:00
# Holyoke               NaN          LIGHT    MA    4/1/1995 18:00
# Holyoke               NaN        DIAMOND    MA  12/28/2000 18:00
# San Diego             NaN          CIGAR    CA    1/1/1944 12:00
# San Diego             NaN           DISK    CA     8/9/1957 0:30
# San Diego             NaN         CIRCLE    CA    6/1/1967 12:00
# San Diego             NaN            NaN    CA   11/10/1968 3:00
# San Diego             NaN           OVAL    CA    5/1/1969 12:00
# San Diego             NaN          LIGHT    CA  10/15/1970 23:00
# San Diego             NaN            NaN    CA    8/15/1973 0:00
# San Diego             NaN            NaN    CA   1/30/1974 23:00
# ...

# %%
ufo.loc[:,['Colors Reported','Shape Reported','State']]
# Out:
#                      Colors Reported Shape Reported State
# City
# Ithaca                           NaN       TRIANGLE    NY
# Willingboro                      NaN          OTHER    NJ
# Holyoke                          NaN           OVAL    CO
# Abilene                          NaN           DISK    KS
# New York Worlds Fair             NaN          LIGHT    NY
# Valley City                      NaN           DISK    ND
# Crater Lake                      NaN         CIRCLE    CA
# Alma                             NaN           DISK    MI
# Eklutna                          NaN          CIGAR    AK
# Hubbard                          NaN       CYLINDER    OR
# Fontana                          NaN          LIGHT    CA
# Waterloo                         NaN       FIREBALL    AL
# Belton                           RED         SPHERE    SC
# Keokuk                           NaN           OVAL    IA
# Ludington                        NaN           DISK    MI
# ...

# %%
ufo.loc[ufo.index=='Franklin',['Colors Reported','Shape Reported','State']]
# Out:
#          Colors Reported Shape Reported State
# City
# Franklin             NaN         SPHERE    TN
# Franklin             NaN           OVAL    KY
# Franklin             NaN      RECTANGLE    TN
# Franklin             NaN         SPHERE    NC
# Franklin             NaN            NaN    NJ
# Franklin             NaN           DISK    KY
# Franklin           GREEN          OTHER    NH
# Franklin             NaN           OVAL    MA
# Franklin             NaN       TRIANGLE    TN
# Franklin        RED BLUE         CIRCLE    NC
# Franklin             NaN            NaN    TN
# Franklin             RED        DIAMOND    MA
# Franklin             NaN           DISK    PA
# Franklin             NaN           DISK    PA
# Franklin             NaN      FORMATION    TN
# Franklin             NaN           DISK    NH

# %%
ufo.loc[ufo['State'].str.endswith("A")]
# Out:
#                  Colors Reported Shape Reported State              Time
# City
# Crater Lake                  NaN         CIRCLE    CA    6/15/1935 0:00
# Fontana                      NaN          LIGHT    CA   8/15/1937 21:00
# Keokuk                       NaN           OVAL    IA     7/7/1939 2:00
# Forest Home                  NaN         CIRCLE    CA    7/2/1941 11:30
# Los Angeles                  NaN            NaN    CA    2/25/1942 0:00
# Hapeville                    NaN            NaN    GA    6/1/1942 22:30
# NaN                          NaN            NaN    LA    8/15/1943 0:00
# NaN                          NaN          LIGHT    LA    8/15/1943 0:00
# San Diego                    NaN          CIGAR    CA    1/1/1944 12:00
# Ft. Lee                      NaN          CIGAR    VA    1/1/1945 12:00
# Salinas AFB                  NaN           DISK    CA    6/1/1945 12:00
# Portsmouth                   RED      FORMATION    VA    7/10/1945 1:30
# ...

# %%
ufo.loc[ufo['State'].isin(['CA','LA','PA'])]
# Out:
#                            Colors Reported Shape Reported State  \
# City
# Crater Lake                            NaN         CIRCLE    CA
# Fontana                                NaN          LIGHT    CA
# Forest Home                            NaN         CIRCLE    CA
# Los Angeles                            NaN            NaN    CA
# NaN                                    NaN            NaN    LA
# NaN                                    NaN          LIGHT    LA
# San Diego                              NaN          CIGAR    CA
# Salinas AFB                            NaN           DISK    CA
# Huntington Beach                       NaN           DISK    CA
# Merced                                 NaN         SPHERE    CA
# Blairsden                            GREEN         SPHERE    CA
# San Deigo                              NaN       TRIANGLE    CA
# Minden                                 NaN            NaN    LA
# Oroville                               NaN            NaN    CA
# ...

# %% [markdown]
# # <b>When selecting columns, if one column only is selected, the .loc operator returns a Series. For a single column DataFrame, use a one-element list to keep the DataFrame format<b>

# %%
type(ufo.loc[ufo.index=='Franklin','Colors Reported'])
# Out:
# pandas.core.series.Series

# %%
ufo.loc[ufo.index=='Franklin','Colors Reported']
# Out:
# City
# Franklin         NaN
# Franklin         NaN
# Franklin         NaN
# Franklin         NaN
# Franklin         NaN
# Franklin         NaN
# Franklin       GREEN
# Franklin         NaN
# Franklin         NaN
# Franklin    RED BLUE
# Franklin         NaN
# Franklin         RED
# Franklin         NaN
# Franklin         NaN
# Franklin         NaN
# Franklin         NaN
# Name: Colors Reported, dtype: object

# %% [markdown]
# # If selections of a single column are made as a string, a series is returned from .loc. Pass a list to get a DataFrame back.

# %%
ufo.loc[ufo.index=='Franklin',['Colors Reported']]
# Out:
#          Colors Reported
# City
# Franklin             NaN
# Franklin             NaN
# Franklin             NaN
# Franklin             NaN
# Franklin             NaN
# Franklin             NaN
# Franklin           GREEN
# Franklin             NaN
# Franklin             NaN
# Franklin        RED BLUE
# Franklin             NaN
# Franklin             RED
# Franklin             NaN
# Franklin             NaN
# Franklin             NaN
# Franklin             NaN

# %%
type(ufo.loc[ufo.index=='Franklin',['Colors Reported']])
# Out:
# pandas.core.frame.DataFrame
