# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset=pd.read_csv('https://raw.githubusercontent.com/jymishra/datasets/master/citizen.csv')

# %%
pd.options.display.max_columns
# Out:
# 20

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.set_option("display.max_rows",200)

# %%
pd.options.display.max_rows
# Out:
# 200

# %%
dataset.head()
# Out:
#    Country   Age  Gender Occupation Employment Status Employement Type  \
# 0   Poland  34.0    Male   Salaried               Yes        Permanent
# 1    Spain  42.0  Female   Business               Yes        Temporary
# 2  Germany  29.0    Male   Business                No        Temporary
# 3    Spain  38.0    Male   Business                No        Permanent
# 4  Germany  32.0    Male   Salaried               NaN        Permanent
#
#     Salary Purchased
# 0  72000.0        No
# 1  48000.0       Yes
# 2  54000.0        No
# 3  61000.0        No
# 4      NaN       Yes

# %%
dataset.describe()
# Out:
#              Age        Salary
# count  17.000000     16.000000
# mean   35.000000  61625.000000
# std     7.399324  10904.891869
# min    22.000000  48000.000000
# 25%    31.000000  53500.000000
# 50%    34.000000  59500.000000
# 75%    38.000000  67750.000000
# max    49.000000  85000.000000

# %%
dataset.tail()
# Out:
#     Country   Age  Gender Occupation Employment Status Employement Type  \
# 15   Brazil  32.0  Female   Business               Yes        Temporary
# 16    Spain   NaN  Female   Salaried               Yes        Temporary
# 17  England  22.0  Female   Salaried               Yes              NaN
# 18  Germany  38.0    Male   Business               Yes              NaN
# 19  England  45.0    Male        NaN               NaN    Self Employed
#
#      Salary Purchased
# 15  58000.0       Yes
# 16  52000.0       Yes
# 17  85000.0       Yes
# 18      NaN        No
# 19  67000.0       Yes

# %%
dataset.isna().sum()
# Out:
# Country              0
# Age                  3
# Gender               0
# Occupation           2
# Employment Status    3
# Employement Type     3
# Salary               4
# Purchased            0
# dtype: int64

# %%
dataset.shape
# Out:
# (20, 8)

# %%
type(dataset.isna().sum())
# Out:
# pandas.core.series.Series

# %%
type(dataset.dropna())
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.dropna().shape
# Out:
# (11, 8)

# %%
dataset.dropna(axis=1).shape
# Out:
# (20, 3)

# %%
dataset1=pd.DataFrame({'a':['Raj','Raj','Hari'],
                            'b':['CTC','BBSR','BAM'],
                            'c':['751010','751001','751025']},index=['a','b','c'])

# %%
dataset1
# Out:
#       a     b       c
# a   Raj   CTC  751010
# b   Raj  BBSR  751001
# c  Hari   BAM  751025

# %%
dataset1.drop_duplicates('a')
# Out:
#       a    b       c
# a   Raj  CTC  751010
# c  Hari  BAM  751025

# %%
dataset
# Out:
#     Country   Age  Gender Occupation Employment Status Employement Type  \
# 0    Poland  34.0    Male   Salaried               Yes        Permanent
# 1     Spain  42.0  Female   Business               Yes        Temporary
# 2   Germany  29.0    Male   Business                No        Temporary
# 3     Spain  38.0    Male   Business                No        Permanent
# 4   Germany  32.0    Male   Salaried               NaN        Permanent
# 5    Poland  31.0  Female   Business               Yes        Temporary
# 6     India   NaN  Female   Salaried               NaN        Temporary
# 7    Poland  22.0  Female   Salaried               Yes    Self Employed
# 8     India  38.0    Male   Business                No              NaN
# 9    Poland  49.0    Male        NaN               Yes    Self Employed
# 10   Brazil  34.0    Male   Salaried                No        Permanent
# 11    Spain  42.0  Female   Business                No        Temporary
# ...

# %%
dataset.drop_duplicates('Occupation')
# Out:
#   Country   Age  Gender Occupation Employment Status Employement Type  \
# 0  Poland  34.0    Male   Salaried               Yes        Permanent
# 1   Spain  42.0  Female   Business               Yes        Temporary
# 9  Poland  49.0    Male        NaN               Yes    Self Employed
#
#     Salary Purchased
# 0  72000.0        No
# 1  48000.0       Yes
# 9  67000.0       Yes

# %%
dataset.drop_duplicates('Occupation',keep='first')
# Out:
#   Country   Age  Gender Occupation Employment Status Employement Type  \
# 0  Poland  34.0    Male   Salaried               Yes        Permanent
# 1   Spain  42.0  Female   Business               Yes        Temporary
# 9  Poland  49.0    Male        NaN               Yes    Self Employed
#
#     Salary Purchased
# 0  72000.0        No
# 1  48000.0       Yes
# 9  67000.0       Yes

# %%
dataset.drop_duplicates('Occupation',keep='last')
# Out:
#     Country   Age  Gender Occupation Employment Status Employement Type  \
# 17  England  22.0  Female   Salaried               Yes              NaN
# 18  Germany  38.0    Male   Business               Yes              NaN
# 19  England  45.0    Male        NaN               NaN    Self Employed
#
#      Salary Purchased
# 17  85000.0       Yes
# 18      NaN        No
# 19  67000.0       Yes

# %%
(dataset.Occupation=='Business').sum()
# Out:
# 10

# %%
dataset.Age.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# Name: Age, dtype: bool

# %%
dataset.shape[0]     #Print Length
# Out:
# 20

# %%
dataset[dataset.Age.isnull()]
# Out:
#     Country  Age  Gender Occupation Employment Status Employement Type  \
# 6     India  NaN  Female   Salaried               NaN        Temporary
# 14  Germany  NaN    Male   Salaried               Yes        Permanent
# 16    Spain  NaN  Female   Salaried               Yes        Temporary
#
#      Salary Purchased
# 6   52000.0        No
# 14      NaN       Yes
# 16  52000.0       Yes

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
# Country              20 non-null object
# Age                  17 non-null float64
# Gender               20 non-null object
# Occupation           18 non-null object
# Employment Status    17 non-null object
# Employement Type     17 non-null object
# Salary               16 non-null float64
# Purchased            20 non-null object
# dtypes: float64(2), object(6)
# memory usage: 1.3+ KB

# %%
dataset[['Country','Age']]
# Out:
#     Country   Age
# 0    Poland  34.0
# 1     Spain  42.0
# 2   Germany  29.0
# 3     Spain  38.0
# 4   Germany  32.0
# 5    Poland  31.0
# 6     India   NaN
# 7    Poland  22.0
# 8     India  38.0
# 9    Poland  49.0
# 10   Brazil  34.0
# 11    Spain  42.0
# 12  Germany  29.0
# 13    Spain  38.0
# 14  Germany   NaN
# 15   Brazil  32.0
# 16    Spain   NaN
# 17  England  22.0
# 18  Germany  38.0
# 19  England  45.0

# %%
dataset.dropna(axis=1)
# Out:
#     Country  Gender Purchased
# 0    Poland    Male        No
# 1     Spain  Female       Yes
# 2   Germany    Male        No
# 3     Spain    Male        No
# 4   Germany    Male       Yes
# 5    Poland  Female       Yes
# 6     India  Female        No
# 7    Poland  Female       Yes
# 8     India    Male        No
# 9    Poland    Male       Yes
# 10   Brazil    Male        No
# 11    Spain  Female       Yes
# 12  Germany  Female        No
# 13    Spain    Male        No
# 14  Germany    Male       Yes
# 15   Brazil  Female       Yes
# 16    Spain  Female       Yes
# 17  England  Female       Yes
# 18  Germany    Male        No
# 19  England    Male       Yes

# %%
dataset.dropna()
# Out:
#     Country   Age  Gender Occupation Employment Status Employement Type  \
# 0    Poland  34.0    Male   Salaried               Yes        Permanent
# 1     Spain  42.0  Female   Business               Yes        Temporary
# 2   Germany  29.0    Male   Business                No        Temporary
# 3     Spain  38.0    Male   Business                No        Permanent
# 5    Poland  31.0  Female   Business               Yes        Temporary
# 7    Poland  22.0  Female   Salaried               Yes    Self Employed
# 10   Brazil  34.0    Male   Salaried                No        Permanent
# 11    Spain  42.0  Female   Business                No        Temporary
# 12  Germany  29.0  Female   Business                No        Temporary
# 13    Spain  38.0    Male   Business                No        Permanent
# 15   Brazil  32.0  Female   Business               Yes        Temporary
#
#      Salary Purchased
# 0   72000.0        No
# 1   48000.0       Yes
# 2   54000.0        No
# ...

# %%
dataset
# Out:
#     Country   Age  Gender Occupation Employment Status Employement Type  \
# 0    Poland  34.0    Male   Salaried               Yes        Permanent
# 1     Spain  42.0  Female   Business               Yes        Temporary
# 2   Germany  29.0    Male   Business                No        Temporary
# 3     Spain  38.0    Male   Business                No        Permanent
# 4   Germany  32.0    Male   Salaried               NaN        Permanent
# 5    Poland  31.0  Female   Business               Yes        Temporary
# 6     India   NaN  Female   Salaried               NaN        Temporary
# 7    Poland  22.0  Female   Salaried               Yes    Self Employed
# 8     India  38.0    Male   Business                No              NaN
# 9    Poland  49.0    Male        NaN               Yes    Self Employed
# 10   Brazil  34.0    Male   Salaried                No        Permanent
# 11    Spain  42.0  Female   Business                No        Temporary
# ...
