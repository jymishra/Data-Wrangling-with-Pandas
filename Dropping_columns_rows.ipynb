# %%
import pandas as pd

# %%
ufo=pd.read_csv("https://raw.githubusercontent.com/jymishra/datasets/master/ufo.csv")

# %%
ufo.shape
# Out:
# (18238, 2)

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.drop_duplicates('City')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
ufo.drop_duplicates('City',keep='last')
# Out:
#                        City Colors Reported Shape Reported State  \
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 6               Crater Lake             NaN         CIRCLE    CA
# 8                   Eklutna             NaN          CIGAR    AK
# 13                   Keokuk             NaN           OVAL    IA
# 14                Ludington             NaN           DISK    MI
# 15              Forest Home             NaN         CIRCLE    CA
# 17                Hapeville             NaN            NaN    GA
# 18                   Oneida             NaN      RECTANGLE    TN
# 19               Bering Sea             RED          OTHER    AK
# 26               Wilderness             NaN           DISK    WV
# 29             Ft. Duschene             NaN           DISK    UT
# 31              North Tampa             NaN       CYLINDER    FL
# 33              Salinas AFB             NaN           DISK    CA
# ...

# %% [markdown]
# # #Specify Axis for Columns

# %%
ufo.drop('Shape Reported')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-7d32dd08c40a> in <module>()
# ----> 1 ufo.drop('Shape Reported')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
ufo.drop('Shape Reported',axis=1).head()
# Out:
#                    City Colors Reported State             Time
# 0                Ithaca             NaN    NY   6/1/1930 22:00
# 1           Willingboro             NaN    NJ  6/30/1930 20:00
# 2               Holyoke             NaN    CO  2/15/1931 14:00
# 3               Abilene             NaN    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN    NY  4/18/1933 19:00

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# # Write inplace=True to return the changed dataset without columns

# %%
ufo.drop('Shape Reported',axis=1,inplace=True)

# %%
ufo.head()
# Out:
#                    City Colors Reported State             Time
# 0                Ithaca             NaN    NY   6/1/1930 22:00
# 1           Willingboro             NaN    NJ  6/30/1930 20:00
# 2               Holyoke             NaN    CO  2/15/1931 14:00
# 3               Abilene             NaN    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN    NY  4/18/1933 19:00

# %%
ufo.head(10)
# Out:
#                    City Colors Reported State              Time
# 0                Ithaca             NaN    NY    6/1/1930 22:00
# 1           Willingboro             NaN    NJ   6/30/1930 20:00
# 2               Holyoke             NaN    CO   2/15/1931 14:00
# 3               Abilene             NaN    KS    6/1/1931 13:00
# 4  New York Worlds Fair             NaN    NY   4/18/1933 19:00
# 5           Valley City             NaN    ND   9/15/1934 15:30
# 6           Crater Lake             NaN    CA    6/15/1935 0:00
# 7                  Alma             NaN    MI    7/15/1936 0:00
# 8               Eklutna             NaN    AK  10/15/1936 17:00
# 9               Hubbard             NaN    OR    6/15/1937 0:00

# %%
ufo.drop(['State','Time'],axis=1,inplace=True)

# %%
ufo.head()
# Out:
#                    City Colors Reported
# 0                Ithaca             NaN
# 1           Willingboro             NaN
# 2               Holyoke             NaN
# 3               Abilene             NaN
# 4  New York Worlds Fair             NaN

# %%
ufo1=pd.read_csv("https://raw.githubusercontent.com/jymishra/datasets/master/ufo.csv")
ufo1.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
cols_to_drop=['City','Time','Colors Reported']
ufo1.drop(cols_to_drop,inplace=True,axis=1)

# %%
ufo1.head()
# Out:
#   Shape Reported State
# 0       TRIANGLE    NY
# 1          OTHER    NJ
# 2           OVAL    CO
# 3           DISK    KS
# 4          LIGHT    NY

# %%
ufo.drop([0,1,2],inplace=True)

# %%
ufo.head(10)
# Out:
#                     City Colors Reported
# 3                Abilene             NaN
# 4   New York Worlds Fair             NaN
# 5            Valley City             NaN
# 6            Crater Lake             NaN
# 7                   Alma             NaN
# 8                Eklutna             NaN
# 9                Hubbard             NaN
# 10               Fontana             NaN
# 11              Waterloo             NaN
# 12                Belton             RED

# %% [markdown]
# In above example 0,1,2,rows has been removed and here axis=0 is default for rows
